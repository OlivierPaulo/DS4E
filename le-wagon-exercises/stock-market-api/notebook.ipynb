# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "https://cloud.iexapis.com/stable/stock/aapl/chart/3m?token=pk_841b11ba596b472eaaa18cf0ed0d9adc"
api_data = requests.get(url).json()

# %%
len(api_data)
# Out:
# 63

# %%
type(api_data)
# Out:
# list

# %%
apple_stock_df = pd.DataFrame.from_dict(api_data)
apple_stock_df["date"] = pd.to_datetime(apple_stock_df["date"])
apple_stock_df.set_index("date")
# Out:
#               open   close    high     low    volume   uOpen  uClose   uHigh  \
# date
# 2020-04-27  281.80  283.17  284.54  279.95  29271893  281.80  283.17  284.54
# 2020-04-28  285.08  278.58  285.83  278.20  28001187  285.08  278.58  285.83
# 2020-04-29  284.73  287.73  289.67  283.89  34320204  284.73  287.73  289.67
# 2020-04-30  289.96  293.80  294.53  288.35  45765968  289.96  293.80  294.53
# 2020-05-01  286.25  289.07  299.00  285.85  60154175  286.25  289.07  299.00
# ...            ...     ...     ...     ...       ...     ...     ...     ...
# 2020-07-20  385.67  393.43  394.00  384.25  22579477  385.67  393.43  394.00
# 2020-07-21  396.69  388.00  397.00  386.97  25911459  396.69  388.00  397.00
# 2020-07-22  386.77  389.09  391.90  386.41  22250413  386.77  389.09  391.90
# 2020-07-23  387.99  371.38  388.31  368.04  49251108  387.99  371.38  388.31
# 2020-07-24  363.95  370.46  371.88  356.58  46359716  363.95  370.46  371.88
#
# ...

# %%
apple_stock_df["close"].plot()

# %%
apple_stock_df[['open','close','high','low']].plot(figsize=(10,8))

# %%
url_lastyear = "https://cloud.iexapis.com/stable/stock/aapl/chart/3m?token='API_KEY'"
url_fb_marketcap = "https://cloud.iexapis.com/stable/stock/fb/quote/marketCap?token='API_KEY'"
url_aapl_r_and_d = "https://cloud.iexapis.com/stable/stock/aapl/financials?token='API_KEY'"
url_tsla_news = "https://cloud.iexapis.com/stable/stock/tsla/news/last/1?token='API_KEY'"
url_energy_sector = "https://cloud.iexapis.com/stable/stock/market/sector-performance?token='API_KEY'"
